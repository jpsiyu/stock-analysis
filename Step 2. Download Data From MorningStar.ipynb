# %% [markdown]
# ## Let's check the base API working or not.

# %%
import pandas as pd
import numpy as np
from urllib import request
from urllib.parse import urlencode
import io

# %%
def downloadData(url, query):
    opener = request.build_opener()
    opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
    request.install_opener(opener)
    
    query = urlencode(urlQuery).encode('utf-8')

    df = pd.DataFrame()
    with request.urlopen(url, data=query) as response:
        data = response.read()
        df = pd.read_csv(io.StringIO(data.decode('utf-8')), header=1, index_col=0)
        print('Good, Down finished!')
    return df
    
code = '000423'
url = 'http://financials.morningstar.com/ajax/ReportProcess4CSV.html'
urlQuery = {
    't': '000423',
    'reportType': 'is',
    'period': 12,
    'dataType': 'A',
    'order': 'asc',
    'columnYear': 10,
    'number': 3,
}
df = downloadData(url, urlQuery)
df.head()
# Out:
# Good, Down finished!
#                                                     2013-12  2014-12  2015-12  \
# Fiscal year ends in December. CNY in millions e...
# Revenue                                              4016.0   4009.0   5450.0
# Cost of revenue                                      1467.0   1381.0   1929.0
# Gross profit                                         2550.0   2628.0   3521.0
# Operating expenses                                      NaN      NaN      NaN
# Sales, General and administrative                    1174.0   1123.0   1700.0
#
#                                                     2016-12  2017-12     TTM
# Fiscal year ends in December. CNY in millions e...
# Revenue                                              6317.0   7372.0  7392.0
# Cost of revenue                                      2088.0   2577.0  2645.0
# Gross profit                                         4230.0   4795.0  4747.0
# ...

# %%
dfT = df.transpose()
dfT.head()
# Out:
# Fiscal year ends in December. CNY in millions except per share data.  Revenue  \
# 2013-12                                                                4016.0
# 2014-12                                                                4009.0
# 2015-12                                                                5450.0
# 2016-12                                                                6317.0
# 2017-12                                                                7372.0
#
# Fiscal year ends in December. CNY in millions except per share data.  Cost of revenue  \
# 2013-12                                                                        1467.0
# 2014-12                                                                        1381.0
# 2015-12                                                                        1929.0
# 2016-12                                                                        2088.0
# ...
