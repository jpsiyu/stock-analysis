# %% [markdown]
# ### Test Financial Simple Module

# %%
from lib.financial_simple import FinancialSimple
fs = FinancialSimple('000423')
fs.fetchData()
fs.df
# Out:
# Read from local finish
#             Average Shares Outstanding (Mil) Capital Spending (Mil)  \
# Fiscal
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013                                       —                -481.08
# 2014                                  654.03                -275.70
# 2015                                  654.01                -284.25
# 2016                                  654.03                -350.60
# 2017                                  654.03                -313.94
# YTD                                   654.02                 -50.85
# TTM                                   654.03                -276.58
# 5-Yr Avg                              654.02                -343.20
# 5-Yr Growth                             0.00                   2.26
#
#             Diluted Earnings Per Share Free Cash Flow (Bil) Net Income (Bil)  \
# Fiscal
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013                              1.84                 0.40             1.20
# ...
