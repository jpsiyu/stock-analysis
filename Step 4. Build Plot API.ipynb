# %% [markdown]
# ### draw line

# %%
from lib import plot_tool
plot_tool.line([2013, 2014, 2015,2016,2017], [4,5,6,7,8], title='测试', xlabel='年份', ylabel='数值')

# %% [markdown]
# ## draw bar

# %%
from lib import plot_tool
plot_tool.bar([2013, 2014, 2015,2016,2017], [4,5,6,7,8], title='测试', xlabel='年份', ylabel='数值')
