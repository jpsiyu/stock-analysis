# %% [markdown]
# ### Key Ratio Data

# %%
from lib.key_ratio import KeyRatio

# %%
keyRatio = KeyRatio('000423')
keyRatio.fetchData()
# Out:
# Read from local finish

# %%
keyRatio.df
# Out:
#      Revenue CNY Mil Gross Margin % Operating Income CNY Mil  \
# Year
# 2008           1,686           49.6                      333
# 2009           2,090           48.8                      447
# 2010           2,464           55.0                      643
# 2011           2,759           66.2                      953
# 2012           3,056           73.6                    1,101
# 2013           4,016           63.5                    1,330
# 2014           4,009           65.5                    1,456
# 2015           5,450           64.6                    1,756
# 2016           6,317           67.0                    2,049
# 2017           7,372           65.0                    2,320
#
#      Operating Margin % Net Income CNY Mil Earnings Per Share CNY  \
# Year
# 2008               19.8                287                   0.44
# 2009               21.4                392                   0.62
# 2010               26.1                582                   0.89
# ...

# %% [markdown]
# ### Book Value Trend

# %%
from lib import plot_tool

# %%
plot_tool.bar(keyRatio.df.index, keyRatio.df['Book Value Per Share * CNY'])

# %% [markdown]
# ### EPS Trend

# %%
plot_tool.bar(keyRatio.df.index, keyRatio.df['Earnings Per Share CNY'])
