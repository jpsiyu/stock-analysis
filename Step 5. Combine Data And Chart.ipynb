# %% [markdown]
# ### Show equity trend

# %%
from lib.balance_sheet import BalanceSheet
from lib import plot_tool

# %%
bs = BalanceSheet('000423')

# %%
bs.fetchData()
# Out:
# Read from local finish

# %%
bs.df.head()
# Out:
#       Assets  Current assets  Cash  Cash and cash equivalents  Total cash  \
# Year
# 2013     NaN             NaN   NaN                     2214.0      2214.0
# 2014     NaN             NaN   NaN                     2550.0      2550.0
# 2015     NaN             NaN   NaN                     1659.0      1659.0
# 2016     NaN             NaN   NaN                     1415.0      1415.0
# 2017     NaN             NaN   NaN                     1725.0      1725.0
#
#       Receivables  Inventories  Prepaid expenses  Other current assets  \
# Year
# 2013        180.0        551.0             206.0                 932.0
# 2014        117.0       1464.0             213.0                1083.0
# 2015        308.0       1725.0             301.0                2440.0
# 2016        386.0       3014.0             230.0                2538.0
# 2017        505.0       3607.0             166.0                3637.0
#
#       Total current assets                     ...                      \
# ...

# %%
bs.df[["Total stockholders' equity"]]
# Out:
#       Total stockholders' equity
# Year
# 2013                      5002.0
# 2014                      5922.0
# 2015                      7014.0
# 2016                      8359.0
# 2017                      9844.0

# %%
plot_tool.bar(bs.df.index, bs.df["Total stockholders' equity"], title='所有者权益')
